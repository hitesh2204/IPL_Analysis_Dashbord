# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("IPL_Dataset/deliveries.csv")
df1=pd.read_csv("IPL_Dataset/ipl.csv")
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df1.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
crick=pd.read_csv("crick_ipl.csv")
crick.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl_ball=pd.read_csv("crick_ipl_ball.csv")
ipl_ball.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
ipl_ball.shape
# Out:
# (225954, 17)

# %%
ipl=crick.merge(ipl_ball,on='ID')
ipl.head()
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 1  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 2  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 3  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
# 4  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 1  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 2  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 3  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
# 4  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ... extra_type batsman_run extras_run  total_run non_boundary  \
# ...

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'innings', 'overs', 'ballnumber',
#        'batter', 'bowler', 'non-striker', 'extra_type', 'batsman_run',
#        'extras_run', 'total_run', 'non_boundary', 'isWicketDelivery',
#        'player_out', 'kind', 'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
len(ipl['batter'].unique())
# Out:
# 605

# %%
ipl_teams=set(list(set(ipl['Team1'])) + list(set(ipl['Team2'])))
len(ipl_teams)
# Out:
# 18

# %%
ipl['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
team.remove('Rising Pune Supergiant')

# %%
team.remove("Pune Warriors")

# %%
team.remove('Rising Pune Supergiants')

# %%
final_df['batting_team'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Mumbai Indians', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants'],
#       dtype=object)

# %%
batsman=final_df.groupby('batting_team')

# %%
 player_name=list(batsman.get_group('Mumbai Indians')['batsman'].unique())

# %%
print(player_name)
# Out:
# ['PA Patel', 'JC Buttler', 'RG Sharma', 'N Rana', 'AT Rayudu', 'KH Pandya', 'KA Pollard', 'HH Pandya', 'TG Southee', 'Harbhajan Singh', 'MJ McClenaghan', 'MG Johnson', 'KV Sharma', 'JJ Bumrah', 'SL Malinga', 'LMP Simmons', 'SS Tiwary', 'L Ronchi', 'ST Jayasuriya', 'DJ Thornely', 'RV Uthappa', 'PR Shah', 'AM Nayar', 'SM Pollock', 'DJ Bravo', 'MA Khote', 'A Nehra', 'DS Kulkarni', 'AM Rahane', 'MK Pandey', 'YV Takawale', 'RR Raje', 'SR Tendulkar', 'DR Smith', 'SD Chitnis', 'CRD Fernando', 'VS Yeligati', 'S Dhawan', 'JP Duminy', 'Z Khan', 'GR Napier', 'C Nanda', 'Mohammad Ashraful', 'AP Tare', 'R Sathish', 'R McLaren', 'AN Ahmed', 'C Madan', 'STR Binny', 'DJ Jacobs', 'JEC Franklin', 'A Symonds', 'AG Murtaza', 'AC Blizzard', 'TL Suman', 'MM Patel', 'RE Levi', 'KD Karthik', 'SA Yadav', 'PP Ojha', 'CJ McKay', 'RP Singh', 'NLTC Perera', 'RJ Peterson', 'HH Gibbs', 'RT Ponting', 'R Dhawan', 'GJ Maxwell', 'NM Coulter-Nile', 'MEK Hussey', 'CJ Anderson', 'CM Gautam', 'BR Dunk', 'S Gopal', 'M de L
# ...

# %%
def batsman_record(batsman):
    print("Total number of runs against each team")
    name=final_df[final_df['batsman']==batsman]
    player=name.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).reset_index()
    print("Name of Player =",batsman)
    b_four=final_df[(final_df['batsman_runs']==4) & (final_df['batsman']==batsman)]
    player['No_Of_fours']=b_four.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
    b_six=final_df[(final_df['batsman_runs']==6) & (final_df['batsman']==batsman)]
    player['NO_Of_sixes']=b_six.groupby('bowling_team')['batsman_runs'].count().sort_values(ascending=False).reset_index()['batsman_runs']
    name=final_df[final_df['batsman']==batsman]
    player['ball_played']=name.groupby('bowling_team')['ball'].count().reset_index()['ball']
    player['Strike_rate']=player['batsman_runs']/player['ball_played']*100
    return player

# %%
#if 'Yuvraj Singh' in player_name:
record=batsman_record('RG Sharma')
pd.DataFrame(record)
# Out:
# Total number of runs against each team
# Name of Player = RG Sharma
#                    bowling_team  batsman_runs  No_Of_fours  NO_Of_sixes  \
# 0              Delhi Daredevils           574           53         28.0
# 1         Kolkata Knight Riders           558           46         24.0
# 2           Chennai Super Kings           535           44         23.0
# 3               Kings XI Punjab           513           43         19.0
# 4   Royal Challengers Bangalore           432           35         18.0
# 5              Rajasthan Royals           403           31         16.0
# 6               Deccan Chargers           175           14          9.0
# 7           Sunrisers Hyderabad           159           13          6.0
# 8                 Pune Warriors           135           10          6.0
# 9                Mumbai Indians           103            7          3.0
# 10       Rising Pune Supergiant            86            6          3.0
# ...

# %%
len(ipl['Team1'].unique())
# Out:
# 18

# %%
df=ipl[(ipl['Team1']== 'Delhi Capitals')&(ipl['Team2']=='Royal Challengers Bangalore')|(ipl['Team1']=='Royal Challengers Bangalore')&(ipl['Team2']== 'Delhi Capitals')]
df.head()
# Out:
#             ID    City        Date Season MatchNumber  \
# 11332  1304073  Mumbai  2022-04-16   2022          27
# 11333  1304073  Mumbai  2022-04-16   2022          27
# 11334  1304073  Mumbai  2022-04-16   2022          27
# 11335  1304073  Mumbai  2022-04-16   2022          27
# 11336  1304073  Mumbai  2022-04-16   2022          27
#
#                              Team1           Team2                     Venue  \
# 11332  Royal Challengers Bangalore  Delhi Capitals  Wankhede Stadium, Mumbai
# 11333  Royal Challengers Bangalore  Delhi Capitals  Wankhede Stadium, Mumbai
# 11334  Royal Challengers Bangalore  Delhi Capitals  Wankhede Stadium, Mumbai
# 11335  Royal Challengers Bangalore  Delhi Capitals  Wankhede Stadium, Mumbai
# 11336  Royal Challengers Bangalore  Delhi Capitals  Wankhede Stadium, Mumbai
#
#            TossWinner TossDecision  ... extra_type batsman_run extras_run  \
# 11332  Delhi Capitals        field  ...        NaN           0          0
# ...

# %%
df['WinningTeam'].value_counts()
# Out:
# Delhi Capitals                 978
# Royal Challengers Bangalore    745
# Name: WinningTeam, dtype: int64

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'innings', 'overs', 'ballnumber',
#        'batter', 'bowler', 'non-striker', 'extra_type', 'batsman_run',
#        'extras_run', 'total_run', 'non_boundary', 'isWicketDelivery',
#        'player_out', 'kind', 'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
win
# Out:
# 7299

# %%
df['WinningTeam'].value_counts().plot(kind='pie',label='winner',autopct='%0.01f%%')
# Out:
# <Axes: ylabel='winner'>

# %%
import matplotlib.pyplot as plt
def team_vs_team(team1,team2):
    df=final_df[(ipl['Team1']==team1)&(ipl['Team2']==team2)|(ipl['Team1']==team2)&(ipl['Team2']==team1)]
    #df.head()
    print(df['WinningTeam'].value_counts()[team1])
    print()
    #plt.pie(final_df,labels='winner',autopct='%0.01f%%')
    #plt.show()

# %%
ipl['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
ipl.groupby('BattingTeam').get_group('Royal Challengers Bangalore')['batter'].unique()
# Out:
# array(['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ Maxwell', 'MK Lomror',
#        'KD Karthik', 'Shahbaz Ahmed', 'PWH de Silva', 'HV Patel',
#        'JR Hazlewood', 'Mohammed Siraj', 'SS Prabhudessai', 'Anuj Rawat',
#        'Akash Deep', 'DJ Willey', 'SE Rutherford', 'D Padikkal',
#        'KS Bharat', 'AB de Villiers', 'DT Christian', 'GHS Garton',
#        'KA Jamieson', 'TH David', 'Sachin Baby', 'YS Chahal', 'DR Sams',
#        'Washington Sundar', 'Navdeep Saini', 'AJ Finch', 'MM Ali',
#        'S Dube', 'JR Philippe', 'CH Morris', 'I Udana', 'Gurkeerat Singh',
#        'UT Yadav', 'DW Steyn', 'PA Patel', 'SO Hetmyer',
#        'C de Grandhomme', 'MP Stoinis', 'H Klaasen', 'P Negi', 'AD Nath',
#        'TG Southee', 'P Ray Barman', 'Mandeep Singh', 'SN Khan',
#        'M Vohra', 'BB McCullum', 'M Ashwin', 'Q de Kock', 'CJ Anderson',
#        'CR Woakes', 'CH Gayle', 'Vishnu Vinod', 'TM Head', 'KM Jadhav',
# ...
